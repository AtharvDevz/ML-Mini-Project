# %% [markdown]
# Using Kaggle API

# %%
# Upload Your Kaggle.json File
# configuring the path of kaggle.json file
# !mkdir -p ~/.Kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !ls ~/.kaggle
# Out:
# kaggle.json

# %%
# !kaggle datasets download -d mlg-ulb/creditcardfraud
# Out:
# creditcardfraud.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# Extracting the zip file
from zipfile import ZipFile
dataset = "/content/creditcardfraud.zip"

with ZipFile(dataset, 'r') as zip:
  zip.extractall()
  print("dataset is Extraxted")
# Out:
# dataset is Extraxted

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv(dataset)

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
# Checking the Number of Missing Values in Each Column
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Checking Distribution of Legit and Fraud Transaction.
data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# Unbalances Dataset cause label are not in Proper Proportion model may learn Wrong data

# %%
# Sepreting data for Analysis
legit = data[data.Class == 0]
print(legit.shape)
fraud = data[data.Class == 1]
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
# Statastical Measure About the data
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# Compare Value for Both Transction
data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# UnderSampling Build Sample dataset Containg Similar Distributon of Normal transaction and Fraud Transaction..

# %%
legit_sample = legit.sample(n=492)

# %%
# Concate Two DataFrame
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 220315  142114.0  0.159760  0.898739 -0.904065 -0.286677  0.393651 -0.485574
# 169806  119870.0  0.013152 -0.471201  1.136312 -0.530967 -1.250183  0.179091
# 248123  153799.0  2.090688 -1.484686  0.040791 -0.803042 -1.418023  0.855868
# 222446  142972.0  0.096836  1.036867 -0.313584 -0.633480  0.961601 -0.577333
# 159692  112815.0 -2.887649  2.880228 -0.838804 -1.627820  0.362004 -0.761532
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 220315  0.127182  0.549139 -0.090054  ...  0.101108  0.181985  0.184391
# 169806 -0.226302 -0.206686 -2.078204  ... -0.438106 -0.371699  0.084306
# 248123 -1.920928  0.521001  1.040636  ...  0.142244  0.581818  0.243184
# 222446  0.910885 -0.005792 -0.405897  ... -0.275348 -0.649498  0.088869
# 159692  1.370695 -0.539463  2.890254  ... -0.828040 -0.775871  0.057535
#
# ...

# %%
new_dataset.shape
# Out:
# (984, 31)

# %%
new_dataset.describe()
# Out:
#                 Time          V1          V2          V3          V4  \
# count     984.000000  984.000000  984.000000  984.000000  984.000000
# mean    87427.981707   -2.350038    1.821569   -3.482869    2.226696
# std     48436.807816    5.515720    3.636340    6.227341    3.216034
# min        73.000000  -30.552380   -8.402154  -31.103685   -3.387554
# 25%     45531.000000   -2.875081   -0.170552   -5.084967   -0.200904
# 50%     79499.000000   -0.697070    0.950405   -1.351650    1.289197
# 75%    135096.750000    1.052034    2.798885    0.417260    4.229802
# max    172496.000000    2.310410   22.057729    3.534419   12.114672
#
#                V5          V6          V7          V8          V9  ...  \
# count  984.000000  984.000000  984.000000  984.000000  984.000000  ...
# mean    -1.596013   -0.716458   -2.783196    0.257452   -1.272860  ...
# std      4.174677    1.694752    5.850226    4.895676    2.319826  ...
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94109.156504  0.071872  0.019359  0.067543 -0.088637 -0.040802
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.035180  0.002340 -0.055732  0.035402  ... -0.006516 -0.079454
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23      V24       V25       V26       V27       V28  \
# Class
# 0     -0.029695  0.010892  0.02734 -0.006026  0.019466 -0.008945  0.023269
# 1      0.014049 -0.040308 -0.10513  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       76.176911
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
# Split Data Train and Test DAta
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify = Y, random_state = 2)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (787, 30)
# (787,)
# (197, 30)
# (197,)

# %%
# MOdel Training
model = LogisticRegression()

# %%
# Training Model With the Data
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Model Evaluation

# %%
X_train_prediction = model.predict(X_train)
accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
accuracy
# Out:
# 0.9428208386277002

# %%
X_test_prediction = model.predict(X_test)
test_accuracy = accuracy_score(X_test_prediction, Y_test)
test_accuracy
# Out:
# 0.9238578680203046

# %%
import pickle
filename = "FraudDetectionModel.sav"
Model = pickle.dump(model , open(filename, 'wb'))

# %%
import matplotlib.pyplot as plt
